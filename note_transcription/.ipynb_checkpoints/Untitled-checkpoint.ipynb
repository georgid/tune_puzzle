# %%
from mir_eval.util import hz_to_midi
import csv
import numpy as np
from mutagen.mp3 import MP3


level = 'One_Line_Regions/'
 

def load_midi(file_ID):
    
    audio = MP3(level + file_ID + '.mp3')
    total_duration = audio.info.length

    notes_MIDI = []
    with open(level + file_ID + '.txt', 'rb') as csvfile:
                score_ = csv.reader(csvfile, delimiter='\t')
                for row in score_:
                        start_ts =  float(row[0]) / total_duration
                        end_ts =  (float(row[0]) + float(row[2]) ) / total_duration
                        midi_freq = hz_to_midi( float(row[1]) )
                        notes_MIDI.append([start_ts, end_ts, midi_freq])
    return notes_MIDI

# %%
track_ID = 'Rihanna'


total_max = 0
total_min = 1000
puzzle_pieces = []
for i in range(1,5):
    a = load_midi(track_ID + str(i))
    b = np.array(a)
        
    puzzle_pieces.append(a)
    
    max_note_MIDI = np.max(b[:,2])
    min_note_MIDI = np.min(b[:,2])
    if max_note_MIDI > total_max:
        total_max = max_note_MIDI
    if min_note_MIDI < total_min:
        total_min = min_note_MIDI
# Out:
# 62.937790599
# 69.6080718556

# %%
for piece in puzzle_pieces:
    print piece
    for note in piece: 
#         print 
#         print note
        note[2] = (note[2] - total_min)   / (total_max-total_min)
# Out:
# [[0.2585831035322777, 0.39999573829824264, 64.883646829402764], [0.4929240410649034, 0.6545384805985732, 66.409615780404891], [0.7474667840612494, 0.9696866385940492, 65.676697002932627]]
#
# [0.2585831035322777, 0.39999573829824264, 64.883646829402764]
#
# [0.4929240410649034, 0.6545384805985732, 66.409615780404891]
#
# [0.7474667840612494, 0.9696866385940492, 65.676697002932627]
# [[0.02424216530363668, 0.14141263406994956, 66.522165736591887], [0.2585831035322777, 0.4646415138333043, 66.053146508378745], [0.6100945098312163, 0.735345700365408, 67.936324687976196], [0.7474667840612494, 0.9696866385940492, 65.082134372776721]]
#
# [0.02424216530363668, 0.14141263406994956, 66.522165736591887]
#
# [0.2585831035322777, 0.4646415138333043, 66.053146508378745]
#
# [0.6100945098312163, 0.735345700365408, 67.936324687976196]
#
# [0.7474667840612494, 0.9696866385940492, 65.082134372776721]
# [[0.26260768192100226, 0.3474552622237689, 62.937790598952276], [0.35151140629893857, 0.4808029580650774, 64.880003203191393], [0.4969644022968505, 0.6828210078301723, 65.000533823463883], [0.7474667840612494, 0.953525194362276, 64.595694988164581]]
#
